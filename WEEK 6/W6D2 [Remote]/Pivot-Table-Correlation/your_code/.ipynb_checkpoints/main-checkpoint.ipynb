# %% [markdown]
# # Before you start :
#    - These exercises are related to the Pivot table and correlation lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import matplotlib.pyplot as plt
import random
import seaborn as sns
import numpy as np
import pandas as pd

# %% [markdown]
# # Challenge 1
#
# #### Read the `employees` dataset from Ironhack's database:
# * db: `employees`
# * table: `employees`
#
# Save your data in a variable called `employees`.

# %%
# your code here
employees = pd.read_csv('../data/Employee.csv')

# %%
employees
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### What's the mean `Salary` by `Department`?
# **Tip**: There are 2 ways to do it: with or without pivot tables. Do it both ways.

# %%
# Method 1
# your code here
employees.groupby(['Department'])[['Salary']].mean()
# Out:
#             Salary
# Department
# HR           45.00
# IT           48.75
# Sales        55.00

# %%
# Method 2
# your code here
employees.pivot_table(index='Department', values='Salary')
# Out:
#             Salary
# Department
# HR           45.00
# IT           48.75
# Sales        55.00

# %% [markdown]
# #### Now, group the data by more than one column. Use Pandas pivot table function to select the mean `Salary` by `Department` and `Title`.

# %%
# your code here
employees.pivot_table(index=['Department','Title'], values='Salary')
# Out:
#                       Salary
# Department Title
# HR         VP           70.0
#            analyst      32.5
# IT         VP           70.0
#            analyst      32.5
#            associate    60.0
# Sales      associate    55.0

# %% [markdown]
# #### Display the number of `Years` of work experience and the `Salary` for each `Title`. Add `Years` as a column in your pivot table.
# **Hint**: Use Pandas documentation to explore the [pivot table](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html) function.

# %%
# your code here
employees.pivot_table(index='Title', columns='Years', values='Salary')
# Out:
# Years         1     2     3     4     7     8
# Title
# VP          NaN   NaN   NaN   NaN   NaN  70.0
# analyst    35.0  30.0   NaN  35.0   NaN   NaN
# associate   NaN  55.0  55.0   NaN  60.0   NaN

# %% [markdown]
# #### Find the mean `Salary` and number of employees in each `Department` and for each job `Title`.

# %%
# your code here
employees.pivot_table(index=['Title', 'Department'], values=['Salary'],
                      aggfunc={'Salary': np.mean, 'Department': 'count'})
# Out:
#                       Department  Salary
# Title     Department
# VP        HR                   1    70.0
#           IT                   1    70.0
# analyst   HR                   2    32.5
#           IT                   2    32.5
# associate IT                   1    60.0
#           Sales                2    55.0

# %% [markdown]
# #### For each `Department` and each job `Title`, find the `Salary` median, minimum, maximum and standard deviation. Comment your results.

# %%
# your code here
employees.pivot_table(index=['Title', 'Department'], values=['Salary'],
                      aggfunc={'Salary': [min, max, np.mean, 'std']})
# Out:
#                      Salary
#                         max  mean   min       std
# Title     Department
# VP        HR           70.0  70.0  70.0       NaN
#           IT           70.0  70.0  70.0       NaN
# analyst   HR           35.0  32.5  30.0  3.535534
#           IT           35.0  32.5  30.0  3.535534
# associate IT           60.0  60.0  60.0       NaN
#           Sales        55.0  55.0  55.0  0.000000

# %%
"""
Ao analisar, podemos ver que alguns cargos 
não possuem desvio padrão por ter apenas 
um registro.
"""
# Out:
# '\nAo analisar, podemos ver que alguns cargos \nnão possuem desvio padrão por ter apenas \num registro.\n'

# %% [markdown]
# #### Based on your comments, fill the missing values with an appropriate value.

# %%
# your code here
employees.pivot_table(index=['Title', 'Department'], values=['Salary'],
                      aggfunc={'Salary': [min, max, np.mean, 'std']},
                      fill_value='0')
# Out:
#                      Salary
#                         max  mean   min      std
# Title     Department
# VP        HR           70.0  70.0  70.0        0
#           IT           70.0  70.0  70.0        0
# analyst   HR           35.0  32.5  30.0  3.53553
#           IT           35.0  32.5  30.0  3.53553
# associate IT           60.0  60.0  60.0        0
#           Sales        55.0  55.0  55.0        0

# %% [markdown]
# #### The stake holders want to know, for each `Department`, the number of employees and how much money is spent on salaries. Could you provide that information?

# %%
# your code here
employees.pivot_table(index=['Department'], values=['Salary'],
                      aggfunc={'Salary': sum},
                      fill_value='0')
# Out:
#             Salary
# Department
# HR             135
# IT             195
# Sales          110

# %% [markdown]
# #### For each `Department` and `Title`, find the the total years of work experience and the mean `Salary`.

# %%
# your code here
employees.pivot_table(index=['Title', 'Department'], values=['Salary', 'Years'],
                      aggfunc={'Salary': np.mean , 'Years':sum},
                      fill_value='0')
# Out:
#                       Salary  Years
# Title     Department
# VP        HR            70.0      8
#           IT            70.0      8
# analyst   HR            32.5      6
#           IT            32.5      3
# associate IT            60.0      7
#           Sales         55.0      5

# %% [markdown]
# ## Bonus Challenge 1
#
# #### Compute the mean `Salary` after removing the maximum `Salary` for each `Department`. Create the appropriate pivot table.
# **Hint**: Write a custom function.

# %%
# your code here

# %% [markdown]
# # Challenge 2
#
# #### Read the `fitbit` dataset from Ironhack's database:
# * db: `fitbit`
# * table: `fitbit`
#
# Save your data in a variable called `fitbit`.

# %%
# your code here
fitbit = pd.read_csv('../data/Fitbit.csv')

# %%
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    08-05-2015            1934    905      0.65       0              1.355
# 1    09-05-2015            3631  18925     14.11       4            611.000
# 2    10-05-2015            3204  14228     10.57       1            602.000
# 3    11-05-2015            2673   6756      5.02       8            749.000
# 4    12-05-2015            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  03-05-2016            3796  18588     14.13      16            599.000
# 363  04-05-2016            3525  16382     12.39      16            684.000
# 364  05-05-2016            3649  21913     16.40      19            701.000
# 365  06-05-2016            3539  19023     14.79      15            575.000
# 366  07-05-2016             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### Explore you dataset in terms of data types and descriptive statistics.
# **Hint**: Use Pandas functions from previous lectures.

# %%
# your code here
fitbit.dtypes
# Out:
# Date                       object
# Calorie burned              int64
# Steps                       int64
# Distance                  float64
# Floors                      int64
# Minutes Sedentary         float64
# Minutes Lightly Active      int64
# Minutes Fairly Active       int64
# Minutes Very Active         int64
# Activity Calories           int64
# MinutesOfSleep              int64
# MinutesOfBeingAwake         int64
# NumberOfAwakings            int64
# LengthOfRestInMinutes       int64
# dtype: object

# %% [markdown]
# #### You suspect that there must be a linear relationship between the `Minutes Very Active` and the `Steps`. Compute the correlation between these variables.

# %%
# your code here
"""
Sim, pois quanto mais tempo de atividades
intensas, maior vai ser o número de passos
que a pessoa irá dar.
"""
# Out:
# '\nSim, pois quanto mais tempo de atividades\nintensas, maior vai ser o número de passos\nque a pessoa irá dar.\n'

# %% [markdown]
# #### Use matplotlib to visually plot `Minutes Very active` vs `Steps`. We'll work with matplotlib next week. As a first introduction, uncomment and complete the following code. You need to replace the # symbol for the correct function arguments.

# %%
import matplotlib.pyplot as plt;

# %%
plt.scatter(fitbit['Minutes Very Active'], fitbit['Steps'], color='magenta')
plt.title('Minutes Very Active X Steps')
plt.xlabel('Minutes Very Active')
plt.ylabel('Steps')
plt.show()

# %% [markdown]
# #### What can you say about `Minutes Very Active` and `Steps`? Write a comment below.

# %%
"""
Podemos ver que mesmo com 0 minutos de muitas
atividades, muitas pessoas deram mais passos 
do que pessoas com maior tempo de atividades.
"""
# Out:
# '\nPodemos ver que mesmo com 0 minutos de muitas\natividades, muitas pessoas deram mais passos \ndo que pessoas com maior tempo de atividades.\n'

# %% [markdown]
# #### We also suspect that there must be a linear relationship between the `Minutes Sedentary` and the `Steps`. Compute the correlation between these variables.

# %%
# your code here
sns.lmplot(x='Minutes Sedentary', y='Steps', data=fitbit)

# %% [markdown]
# #### Use matplotlib to visually plot `Minutes Sedentary` vs `Steps`. Based on the results of the computed correlation and the plot, what can you say about these 2 variables?

# %%
# your code here
plt.scatter(fitbit['Minutes Sedentary'], fitbit['Steps'], color='magenta')
plt.title('Minutes Sedentary X Steps')
plt.xlabel('Minutes Sedentary')
plt.ylabel('Steps')
plt.show()

# %%
"""
Podemos visualizar que a concentração está em 
torno de 15000 steps X 700 Minutes Sedentary.
"""
# Out:
# '\nPodemos visualizar que a concentração está em \ntorno de 15000 steps X 700 Minutes Sedentary.\n'

# %% [markdown]
# #### We also suspect that there must be a linear relationship between the `MinutesOfSleep` and the `Steps`. Compute the correlation between these variables.

# %%
# your code here
sns.lmplot(x='MinutesOfSleep', y='Steps', data=fitbit)

# %% [markdown]
# #### Use matplotlib to visually plot `MinutesOfSleep` vs `Steps`. Based on the results of the computed correlation and the plot, what can you say about these 2 variables?

# %%
# your code here
plt.scatter(fitbit['MinutesOfSleep'], fitbit['Steps'], color='magenta')
plt.title('MinutesOfSleep X Steps')
plt.xlabel('MinutesOfSleep')
plt.ylabel('Steps')
plt.show()

# %%
"""
Há um grau maior de dispersão nesta relação ao compararmos 
com a relação da questão anterior, de Minutes Sedentary X
Steps.
"""
# Out:
# '\nHá um grau maior de dispersão nesta relação ao compararmos \ncom a relação da questão anterior, de Minutes Sedentary X\nSteps.\n'

# %% [markdown]
# #### Select a subset of your dataset with the columns below and compute the correlation matrix. Save the results in the variable `cor_fit`.

# %%
columns = ['Calorie burned', 'Steps', 'Floors', 'Minutes Sedentary', 'Minutes Very Active', 'MinutesOfSleep']

# %%
# your code here
cor_fit = fitbit[columns].corr().style.background_gradient(cmap='coolwarm')
cor_fit
# Out:
# <style  type="text/css" >
#     #T_0c01323a_79bf_11ea_83d6_78843c96b14arow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0c01323a_79bf_11ea_83d6_78843c96b14arow0_col1 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_0c01323a_79bf_11ea_83d6_78843c96b14arow0_col2 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_0c01323a_79bf_11ea_83d6_78843c96b14arow0_col3 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_0c01323a_79bf_11ea_83d6_78843c96b14arow0_col4 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_0c01323a_79bf_11ea_83d6_78843c96b14arow0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c01323a_79bf_11ea_83d6_78843c96b14arow1_col0 {
#             background-color:  #8caffe;
#             color:  #000000;
# ...

# %%
fitbit.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_0c250e74_79bf_11ea_827b_78843c96b14arow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0c250e74_79bf_11ea_827b_78843c96b14arow0_col1 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_0c250e74_79bf_11ea_827b_78843c96b14arow0_col2 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_0c250e74_79bf_11ea_827b_78843c96b14arow0_col3 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_0c250e74_79bf_11ea_827b_78843c96b14arow0_col4 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_0c250e74_79bf_11ea_827b_78843c96b14arow0_col5 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_0c250e74_79bf_11ea_827b_78843c96b14arow0_col6 {
#             background-color:  #a7c5fe;
#             color:  #000000;
# ...

# %% [markdown]
# #### Based on the result of the correlation matrix, which of the features are highly correlated with variable `Steps`?
# **Hint**: sort the correlations of `Steps` vs the rest of the features in descending order. You can use Pandas `sort_values`.

# %%
# your code here

# %% [markdown]
# # Challenge 3
#
# #### Read the `time_grades` dataset from Ironhack's database:
# * db: `time_grades`
# * table: `time_grades`
#
# Save your data in a variable called `time_grades`.

# %%
# your code here
time_grades = pd.read_csv('../data/Time_Grades.csv')

# %%
time_grades.head(5)
# Out:
#      Name  Study time  Grade
# 0    Jose           4      4
# 1   Maria           9      7
# 2   David           8      9
# 3   Sonia          10      7
# 4  Samuel          20      9

# %% [markdown]
# #### Show visually the frequency distribution of the `time_grades` dataset.

# %%
# your code here
time_grades.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000BEBF1C8>,
# ...
#       dtype=object)

# %% [markdown]
# #### Is there a correlation between `Study time` and `Grade`? Use both Pearson and Spearman correlations and comment your results.

# %%
# your code here
time_grades.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_c03c6ffa_79c0_11ea_b68d_78843c96b14arow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c03c6ffa_79c0_11ea_b68d_78843c96b14arow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c03c6ffa_79c0_11ea_b68d_78843c96b14arow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c03c6ffa_79c0_11ea_b68d_78843c96b14arow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_c03c6ffa_79c0_11ea_b68d_78843c96b14a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Study time</th>        <th class="col_heading level0 col1" >Grade</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c03c6ffa_79c0_11ea_b68d_78843c96b14alevel0_row0" class="row_heading level0 row0" >Study time</th>
# ...

# %%
sns.lmplot(x='Study time', y='Grade', data=time_grades)

# %%
"""
Podemos ver que a relação entre as duas
variáveis são proporcionais, pois maior 
parte das pessoas que estudam por mais 
tempo, maior será a nota das pessoas.
"""
# Out:
# '\nPodemos ver que a relação entre as duas\nvariáveis são proporcionais, pois maior \nparte das pessoas que estudam por mais \ntempo, maior será a nota das pessoas.\n'

# %% [markdown]
# #### Use matplotlib to visually plot `Study time` vs `Grade`. Based on the results of the computed correlation and the plot, what can you say about these 2 variables?

# %%
# your code here
plt.scatter(time_grades['Study time'], time_grades['Grade'], color='magenta')

# %%
"""
Podemos ver que a relação entre as duas
variáveis são proporcionais, pois maior 
parte das pessoas que estudam por mais 
tempo, maior será a nota das pessoas.
"""
# Out:
# '\nPodemos ver que a relação entre as duas\nvariáveis são proporcionais, pois maior \nparte das pessoas que estudam por mais \ntempo, maior será a nota das pessoas.\n'

# %% [markdown]
# #### Could you explain the difference between Pearson and Spearman correlations?

# %%
"""
Spearman - Quanto maior o ângulo de inclinação, maior a correlação
Pearsom - Quanto mais o valor está próximo a 1, maior será a correlação.
"""
# Out:
# '\nSpearman - Quanto maior o ângulo de inclinação, maior a correlação\nPearsom - Quanto mais o valor está próximo a 1, maior será a correlação.\n'
