# %% [markdown]
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# # ^^^ pyforest auto-imports - don't write above this line
# # Before your start:
#
# - Comment as much as you can and use the resources
# - Happy learning!

# %% [markdown]
# # Challenge 1 - Reading and Standardizing the Data
#
# In this challenge we will work with image data and reduce the dimensions of the data to create a 2 dimensional plot. While we have not worked much with image data before, it can be represented as a numpy array where each pixel is assigned a numeric value. In this lesson, we will look at a dataset of cats and a dataset of dogs and see whether reducing them to two dimensions allows us to see if the data is separable. We will start by loading and processing the data. Run the cell below to load the two csv files and convert them into numpy arrays.

# %% [markdown]
# ## Read the files into dataframes named `dogs` and `cats`

# %%
import pandas as pd

# %%
#your code here

# %%
dogs = pd.read_csv('../data/dogs.csv')
cats = pd.read_csv('../data/cats.csv')

# %% [markdown]
# Next, we'll examine the shape of both the cats and the dogs arrays. Print out both shapes below.

# %%
# Your code here:
print(dogs.shape)
print(cats.shape)
# Out:
# (80, 4096)
# (80, 4096)

# %% [markdown]
# What this means is that both arrays contain 80 images each (the number of rows). Each image is comprised of 64x64 pixels (so a total of 4096 pixels per image). The images have been flattened such that all 4096 are in a single row.
#
# Print out row 0 of the cats dataframe to see what the pixels values look like.

# %%
# Your code here:
cats.loc[0,:]
# Out:
# 0       64
# 1       64
# 2       64
# 3       64
# 4       64
#         ..
# 4091    77
# 4092    64
# 4093    61
# 4094    61
# 4095    61
# Name: 0, Length: 4096, dtype: int64

# %% [markdown]
# Using `matplotlib` we can plot a single cat or a single dog. We do this by reshaping the observation vector back to a squared image and then using the `imshow` function.
#
# Plot the image of the first cat and dog of your dataframes
#
# _Extra: you can play with `imshow`'s argument `cmap` to see which colors are suitable for visualization_

# %%
import matplotlib.pyplot as plt

# %%
# your code here
fig, ax = plt.subplots(8, 8, figsize=(12, 12))
for i, axi in enumerate(ax.flat):
    axi.imshow(cats.loc[i,:].values.reshape(64,64), cmap='gray')

# %%
fig, ax = plt.subplots(8, 8, figsize=(12, 12))
for i, axi in enumerate(ax.flat):
    axi.imshow(dogs.loc[i,:].values.reshape(64,64), cmap='gray')

# %% [markdown]
# Now concatenate the cats and dogs dataframes. Make sure to put dogs first. This should result in a dataframe containing 160 observations and 4096 dimensions.

# %%
# your code here
df = dogs.append(cats, ignore_index=True)

# %%
fig, ax = plt.subplots(16, 10, figsize=(12, 12))
for i, axi in enumerate(ax.flat):
    axi.imshow(df.loc[i,:].values.reshape(64,64), cmap='gray')

# %% [markdown]
# Next, we would like to standardize our data.
#
# In order to do that, we will need to use the `StandardScaler` class from `sklearn.preprocessing` module.
#
# Remember, we need to standardize the information for each pixel (which are the dimensions of our dataset) so that they can be compared in the PCA algorithm. Otherwise, the result would be dominated by the variable with the highest scale.

# %%
from sklearn.preprocessing import StandardScaler

# %%
# your code here
scaler = StandardScaler()
scaler.fit_transform(df)
dfs = pd.DataFrame(scaler.fit_transform(df))

# %% [markdown]
# ## Bonus
#
# After standardizing your data, try visualizing your image again. Does the standardization changes your original image?

# %%
# your code here
fig, ax = plt.subplots(16, 10, figsize=(12, 12))
for i, axi in enumerate(ax.flat):
    axi.imshow(dfs.loc[i,:].values.reshape(64,64), cmap='gray')

# %% [markdown]
# # Challenge 2 - Using PCA
#
# Now that we have created a standardized matrix of cats and dogs, we'll find the two most important components in the data.
#
# Load the PCA from sklearn (https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html) and apply the function to our standarized data. Create a PCA model with two components.

# %%
from sklearn.decomposition import PCA

# %%
# Your code here:
pca = PCA(n_components=2)
pca.fit_transform(df)
# Out:
# array([[ 4.55449814e+01, -2.52389391e+01],
#        [-2.48328587e+01, -4.15716864e+01],
#        [ 2.74692450e+01,  1.19581866e+01],
#        [-2.25998546e+01, -9.83936157e+00],
#        [ 1.93603564e+01, -1.88120255e+01],
#        [-4.74468664e+00,  5.84375008e+00],
#        [-2.06260501e+01, -2.06659205e+01],
#        [-1.29788491e+01, -2.02951053e+01],
#        [ 1.50642297e+01, -9.17913009e+00],
#        [ 2.00937359e+01, -3.18338068e+01],
#        [-4.07943695e-01, -2.65321341e+00],
#        [ 3.20386915e+01, -4.98633238e+00],
#        [-3.36053890e+01, -1.17071942e+01],
#        [ 4.22857896e+01,  7.38833515e+00],
#        [ 5.59330677e+00, -2.05419467e+01],
#        [ 1.20688731e+01, -1.10092743e+01],
#        [ 1.77230667e+01, -1.11085933e+01],
#        [ 1.47700211e+00, -3.37994261e+01],
#        [ 2.00562708e+01, -8.98499954e+00],
#        [ 2.60924376e+01, -1.48999554e+01],
#        [ 2.09878872e+01,  4.65157560e+00],
#        [-9.44574138e+00, -7.50716998e+00],
#        [ 4.20501316e+01, -6.94592741e-01],
#        [-4.51769749e+01, -2.52214588e+01],
#        [-2.58030776e+01, -3.47407886e+01],
#        [-4.17589606e+01, -1.18016319e+01],
#        [ 4.16831369e+01,  8.45781160e+00],
#        [ 8.09341824e+00, -2.78416063e-02],
#        [ 1.18571978e+01, -1.96098682e+01],
#        [-2.38766123e+01, -1.45359638e+01],
#        [-6.80805729e+00, -7.77316854e+00],
#        [-3.26630246e+01, -1.32496287e+01],
#        [ 2.41970204e+00, -3.04898420e+01],
#        [-5.57199837e+01, -2.70190765e+01],
#        [-3.88382036e+01, -2.26125122e+00],
#        [-1.88022890e+01, -1.83870889e+01],
#        [ 1.94022697e+01,  1.05983117e+01],
#        [-4.07353489e+01, -1.11855776e+01],
#        [-5.34214805e+01, -6.18164695e+00],
#        [-2.02565644e+01, -3.38638945e+01],
#        [-1.47710894e+01, -2.03887427e+01],
#        [ 2.15738737e+01,  1.48479780e+00],
#        [-6.16642615e+01, -6.92920684e+00],
#        [-3.46099485e+01, -2.04911832e+01],
#        [-1.69707147e+01,  3.61589080e+00],
#        [-8.49060180e+00, -1.94840037e+01],
#        [-5.40501871e+00, -3.00119280e+01],
#        [-3.43065826e+01, -1.06191535e+01],
#        [ 1.08835958e+01, -1.11539365e+01],
#        [-4.79221794e+01,  2.38753589e+00],
#        [ 7.16522712e+00, -2.32554650e+01],
#        [ 6.80187482e+01, -1.39848807e+01],
#        [ 6.59248277e+01,  9.36353915e+00],
#        [ 3.71766661e+00,  1.68701793e+01],
#        [-7.39124230e+00,  1.39425054e+01],
#        [ 1.98091877e+01,  2.05814120e+01],
#        [ 1.64148200e+01, -1.72494917e+01],
#        [ 3.90420737e+00, -8.23684041e+00],
#        [-7.91964851e+00,  1.04854149e+01],
#        [ 6.87527463e+00, -1.27949487e+00],
#        [-1.29811046e+01, -1.12601245e+01],
#        [ 1.16714780e+01, -1.69463927e+01],
#        [-2.71142880e+00, -2.83606290e+01],
#        [ 3.41719358e+01,  2.12993150e+01],
#        [-6.06165087e+01,  1.38072021e-02],
#        [-1.12311472e+01, -2.50461769e+01],
#        [ 3.85956398e+01,  2.62671055e+00],
#        [-5.53081938e+00,  3.43986389e+01],
#        [-1.85537095e+01,  1.11758073e+00],
#        [ 4.53223365e-01, -2.37046258e+01],
#        [-3.47121723e+01,  2.78683376e+00],
#        [-3.18957089e+01, -6.30267291e+00],
#        [ 2.69830461e+00, -2.92934185e+01],
#        [-4.78385678e+01,  3.66654205e+00],
#        [ 2.28983086e+01, -7.18764372e-01],
#        [ 1.54539973e+00, -2.75389308e+01],
#        [ 1.43333820e+01, -2.79821608e+01],
#        [-2.47792406e+00,  4.50789203e+00],
#        [-3.16194286e+01, -5.73763977e+00],
#        [ 3.31035023e+01, -3.16377846e+01],
#        [ 6.52548943e+01,  2.97016473e+01],
#        [-8.34652773e-01,  3.87785833e+01],
#        [ 6.56103083e+01, -5.27871292e+01],
#        [ 4.88917964e+01, -1.71002985e+01],
#        [ 5.05344878e+01,  3.82485637e+01],
#        [-9.10950497e-01,  2.53107491e+01],
#        [ 2.67613445e+01,  3.87952113e+01],
#        [ 2.17168454e+01,  9.86117053e+00],
#        [-1.36696542e+01,  4.13242760e+01],
#        [-1.93446365e+01,  2.41138801e+01],
#        [-1.02984546e+01, -8.49835763e-01],
#        [-4.35232289e+01, -1.15878408e+01],
#        [-3.07031753e+01,  4.64827440e+01],
#        [ 3.23262813e+01,  3.31604481e+01],
#        [ 7.98537190e+00, -1.88340348e+01],
#        [ 3.34022667e+00,  1.94269279e+01],
#        [ 9.89283375e+00, -1.78926026e+01],
#        [ 2.76965026e+01,  3.27709878e+01],
#        [ 4.14195791e+01, -2.44113497e+01],
#        [-4.38032467e+01,  3.32806848e+01],
#        [ 7.02188041e+01,  6.98871410e+00],
#        [-2.28977933e+01,  3.56357004e+01],
#        [-4.24639053e+01,  2.08220798e+01],
#        [-5.92480015e+01,  1.24809180e+01],
#        [ 7.03243028e+01, -3.87340016e+01],
#        [-7.96192394e+00,  8.17403307e-01],
#        [ 3.10898764e+01,  3.28090175e+01],
#        [-6.20723420e+01,  1.68565281e+01],
#        [ 1.78105347e+00, -1.38221516e+01],
#        [ 6.67199635e+00,  1.69211327e+01],
#        [ 3.03690255e+01,  9.05563197e+00],
#        [ 6.44798520e+01,  3.73654939e+00],
#        [ 2.86422936e+01,  2.66857866e+01],
#        [ 8.43104802e+01, -5.05263179e+01],
#        [-7.87747891e+00,  3.24784682e+01],
#        [-5.89322299e+01, -7.39974544e+00],
#        [ 3.65943232e+01, -4.06109131e+01],
#        [-2.69192775e+01,  3.13985745e+01],
#        [-2.61188932e+01,  8.34119650e+00],
#        [ 6.93550966e+01,  2.48364610e+01],
#        [-1.17720450e+01,  5.24285862e+00],
#        [ 5.17879633e+01,  4.76857787e+01],
#        [-3.70889565e+01,  3.96302644e+01],
#        [-5.54627820e+01,  1.00027491e+01],
#        [-7.15593930e+01,  4.28777925e+01],
#        [-5.48242360e+01, -2.37532668e+01],
#        [-5.83219104e+01, -2.57482935e+01],
#        [-2.20906495e+01, -3.25172711e+01],
#        [-1.57682697e+01,  4.80486920e+01],
#        [ 2.06420992e+01,  5.80581178e+00],
#        [ 5.13505932e+01,  3.71342392e+01],
#        [ 8.47441409e+00,  1.00488276e+01],
#        [ 3.56303289e+00,  4.15353750e+01],
#        [-2.15207497e+01,  3.40154196e+01],
#        [-2.47071506e+01, -1.19415449e+01],
#        [ 1.86179321e+00,  2.81638106e+01],
#        [ 1.75859885e+01,  5.56905139e+01],
#        [-7.90413951e+00,  1.14483343e+01],
#        [ 1.34979992e+01, -1.75573130e+01],
#        [-4.20364641e+01,  5.33339013e+00],
#        [-1.03074053e+01, -2.35444893e+00],
#        [ 2.81309757e+01,  1.85459770e+01],
#        [ 2.75842859e+01,  3.98654658e+01],
#        [-2.79618689e+01,  2.83687740e+01],
#        [-1.09978083e+01, -2.37699960e+01],
#        [ 2.22051833e+00,  8.39831226e+00],
#        [ 3.17988981e+01, -4.11899281e+01],
#        [ 3.23313987e+01,  1.09174410e+01],
#        [-4.05853847e+00, -9.76186533e+00],
#        [-2.30645416e+01, -3.10497921e+01],
#        [ 6.47071678e+00, -8.20261314e+00],
#        [-5.83244513e+00,  2.63484575e+01],
#        [ 2.15021386e+01,  1.20313712e+01],
#        [ 1.04234612e+01, -1.90159359e-01],
#        [ 1.57983992e+01, -5.51454073e+00],
#        [-5.40205335e-01,  1.52939305e+01],
#        [-1.67015977e+01,  2.08983954e+01],
#        [-1.87184273e+01,  2.08673854e+01],
#        [-1.43264083e+01, -1.43343840e+01],
#        [ 1.04550095e+01,  8.36671688e+00]])

# %%
print(pca.explained_variance_ratio_)
print(pca.singular_values_)
# Out:
# [0.25550287 0.13038508]
# [409.20209905 292.31689333]

# %% [markdown]
# After instantiating the `PCA class` and applying it to the standardized data, the results of your principal component analysis will be stored on the PCA object you've created (from the PCA class).

# %% [markdown]
# # Challenge 3 - Plotting the Data
#
# Now that we have reduced our cats and dogs arrays, we can plot the data in a way that the human eye can understand in 2-D. We can look at this plot to see whether there are differences between the cat and dog images.
#
# In the cell below, create a pandas dataframe containing the columns `pc1`, and `pc2` with the results of the first and second components of your results, respectively.

# %%
# Your code here:
dfp = pd.DataFrame(pca.fit_transform(df), columns= ['pc1', 'pc2']).reset_index()

# %% [markdown]
# Create a labels list. This list will be of size 160. The first 80 elements in the list will be the word `blue`, and the last 80 elements will be `red`. This will ensure that all dog observations will be colored in blue and all cats will be colored in red. Name this list `colors`.

# %%
# Your code here:
for item in range(0, 160):
    if dfp['index'][item] < 80:
        dfp['label'][item] = 'pc1'
    else:
        dfp['label'][item] = 'pc2'
labels = ['pc1', 'pc2']
colors = ['blue', 'red']
# Out:
# C:\Users\yukar\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\yukar\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# Create a scatter plot of `pc1` and `pc2` below. Use the `colors` list above to color the observations by setting `c=colors`.

# %%
# Your code here:
for label, color in zip(labels,colors):
    indices = dfp['label'] == label
    plt.scatter(dfp.loc[indices, 'pc1'],
                dfp.loc[indices, 'pc2'], c = color)

# %% [markdown]
# Do you see a clear separation between cats and dogs? Write your answer below.

# %%
# Your conclusions here:
"""
A separação não é nítida.
"""
# Out:
# '\nA separação não é nítida.\n'

# %% [markdown]
# # Evaluate the results

# %% [markdown]
# Calculate how much explained variance do the results of your PCA has lead to.

# %%
# Your code here:
print(pca.explained_variance_ratio_)
# Out:
# [0.25550287 0.13038508]

# %% [markdown]
# Explain with your own words what those values represent.

# %%
# your answer here:
"""
O primeiro valor, indica que 25,55% da variância
do conjunto está ao longo do primeiro eixo e 13%
situa-se no segundo eixo.
"""
# Out:
# '\nO primeiro valor, indica que 25,55% da variância\ndo conjunto está ao longo do primeiro eixo e 13%\nsitua-se no segundo eixo.\n'

# %% [markdown]
# # Bonus Challenge
#
#
# Recreate your PCA using 20 components. You'll not be able to visualize the results this time, but the idea here is to plot a cumulative sum of your explained variance results. Follow the steps as before (i.e, create a dataframe containing the 20 components and so on)
#
#
# What do you observe? How much of the information is retained after going from 4096 to 20 dimensions?

# %%
pca = PCA(n_components=20)
X_t = pca.fit_transform(df)
dfp20 = pd.DataFrame(pca.fit_transform(df))
print(pca.explained_variance_ratio_)
# Out:
# [0.25550287 0.13038508 0.0760708  0.05006292 0.04331911 0.03296438
#  0.02638495 0.0231017  0.01997537 0.01732064 0.01564318 0.0136954
#  0.01177953 0.01069128 0.01047296 0.00988326 0.00928299 0.00844627
#  0.00812548 0.00767858]

# %% [markdown]
# # Bonus Challenge 2

# %% [markdown]
# Use the `.inverse_transform()` method to the dataframe with the 20 components and store your results. The inverse transform takes the results of the PCA (the reduced dimension space) and take it back to the original space (with 4096 dimensions). This will be helpful for you to visualize how the PCA affected the original data.

# %%
# your code
pca.inverse_transform(X_t)
# Out:
# array([[ 1.589565  ,  1.67558706,  1.66157641, ...,  0.28807597,
#          0.35935757,  0.49663738],
#        [ 0.7284217 ,  0.8033809 ,  0.89495435, ...,  0.04249961,
#          0.33865478,  0.45918434],
#        [-0.21570163, -0.18423945, -0.16076671, ...,  0.11531889,
#          0.07147132,  0.06297195],
#        ...,
#        [-0.77500459, -0.78249098, -0.7473046 , ...,  0.2366212 ,
#          0.15705022,  0.11447218],
#        [ 1.77367923,  1.72661479,  1.70035621, ...,  1.32291346,
#          1.18969377,  1.12630389],
#        [ 0.23859741,  0.21680449,  0.20795208, ..., -0.3349311 ,
#         -0.39525874, -0.37842419]])

# %% [markdown]
# Use the `imshow` to plot the first row of the `inverse_transform` of the results. Compare the results with the original image.

# %%
# your code
dfi = pd.DataFrame(pca.inverse_transform(X_t))
fig, ax = plt.subplots(16, 10, figsize=(12, 12))
for i, axi in enumerate(ax.flat):
    axi.imshow(dfi.loc[i,:].values.reshape(64,64), cmap='gray')

# %% [markdown]
# Change the value of the components above to have a feeling of the information retained (try 100 components).

# %%
pca = PCA(n_components=100)
X_t = pca.fit_transform(df)
pca.inverse_transform(X_t)
# Out:
# array([[ 1.64127742,  1.61438514,  1.49411025, ..., -0.17486925,
#         -0.13706306,  0.08610589],
#        [ 0.38644701,  0.38001784,  0.50672724, ..., -0.80540602,
#          0.00924239,  0.35118597],
#        [ 0.45745287,  0.45761658,  0.44217306, ...,  0.3239557 ,
#          0.21394382,  0.31630438],
#        ...,
#        [-0.46849842, -0.59993773, -0.49630458, ...,  0.02474646,
#          0.12450785,  0.20427256],
#        [ 1.82739313,  1.8024862 ,  1.7248878 , ...,  1.15444782,
#          1.18505054,  1.17390711],
#        [-0.01823748,  0.1100639 ,  0.35079755, ...,  0.1056319 ,
#          0.04719566, -0.09366357]])

# %%
dfi100 = pd.DataFrame(pca.inverse_transform(X_t))
fig, ax = plt.subplots(16, 10, figsize=(12, 12))
for i, axi in enumerate(ax.flat):
    axi.imshow(dfi100.loc[i,:].values.reshape(64,64), cmap='gray')

# %% [markdown]
# The results above demonstrate the power of the PCA analysis. It takes the best combination of your columns in such a way that it preserves the most of its information. So, although you lose some of the information, you effectively reduce the number of dimensions on your dataset. This can be important both for visualization purposes as well as for understanding the importance of each feature.
